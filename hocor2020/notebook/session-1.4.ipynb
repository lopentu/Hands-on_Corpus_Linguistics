# %% [markdown]
# # HOCOR2020 Session 1.4 語言處理管線

# %% [markdown]
# ## 環境設置

# %%
# !pip install jieba
# !pip install ckiptagger[tf,gdown]
# !pip install CwnGraph DistilTag CwnSenseTagger
# !mkdir /content/ckiptagger
# !gdown --id 1_-y2P_BrbSltZsDtw1IosYsnOOZMWIRi -O data_1.4.zip && unzip -o data_1.4.zip
# !curl -OL https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big

# %%
import jieba
import json
jieba.set_dictionary('dict.txt.big')
with open("data_1.4/corpus-wiki.json", "r", encoding="UTF-8") as fin:
    corpus = json.load(fin)

# %%
corpus[:2]
# Out:
# [{'preproc': ['語音學（、發音：）是研究言語聲音（即語音）的語言學分支學科。',
#    '狹義的語音學對應英語中發音一詞，關切的重點在語音的物理、生物、心理等具象本質，與語音的實際用途、表達意義無關。',
#    '與之相對的是音韻學（或稱音系學），研究音位或語音區別特徵在某種語言中運作的抽象規則和語音的系統。',
#    '廣義的語音學是指這兩大方面研究的總合。',
#    '本文介紹的是狹義的語音學。',
#    '語音是語音學研究的客體，指的是人類說話時發出的具體聲音，即言語的聲音。',
#    '國際語音學學會所制訂的國際音標是語言學界廣泛用來標註語音的音標方案。',
#    '學科分支語音學的研究範疇包括以下三類：發音語音學：此分科研究發音器官（如脣、齒、舌、聲門等）如何彼此協調動作，以發出語音。',
#    '聲學語音學：此分科研究語音的物理現象，如聲波的頻率、時長、振幅等。',
#    '聽覺語音學：此分科研究語音的感知歷程。',
#    '歷史現代語音學的最早發展是為了發明出一套記錄語音的記號系統。',
#    '世紀後期，留聲機的出現令到聲音的研究更為方便，令到語音學快速發展。'],
#   'query': '語音學',
#   'rawtext': '語音學（Phonetics、發音：/fəˈnɛtɪks/）是研究言語聲音（即語音）的語言學分支學科。狹義的語音學對應英語中phonetics(發音)一詞，關切的重點在語音的物理、生物、心理等具象本質，與語音的實際用途、表達意義無關。與之相對的是音韻學（或稱音系學），研究音位或語音區別特徵在某種語言中運作的抽象規則和語音的系統。廣義的語音學是指這兩大方面研究的總合。本文介紹的是狹義的語音學。\n語音是語音學研究的客體，指的是人類說話時發出的具體聲音，即言語的聲音。\n國際語音學學會所制訂的國際音標是語言學界廣泛用來標註語音的音標方案。\n\n\n== 學科分支 ==\n語音學的研究範疇包括以下三類：\n\n發音語音學 (articulatory phonetics)：此分科研究發音器官（如脣、齒、舌、聲門等）如何彼此協調動作，以發出語音。\n聲學語音學 (acoustic phonetics)：此分科研究語音的物理現象，如聲波的頻率、時長、振幅等。\n聽覺語音學 (auditory phonetics)：此分科研究語音的感知歷程。\n\n\n== 歷史 ==\n現代語音學的最早發展是為了發明出一套記錄語音的記號系統。19世紀後期，留聲機的出現令到聲音的研究更為方便，令到語音學快速發展。\n\n\n== 註釋 ==\n\n\n== 參考文獻 ==\n\n\n== 參見 ==\n\n實驗語音學\n\n\n== 外部鏈接 ==\n\n國際語音學學會\nOn-line phonetics course',
#   'title': '語音學'},
#  {'preproc': ['詞法學（英語：，“組織與形態”），又稱形態學、構詞學，是語言學的一個分支，研究單詞（）的內部結構和其形成方式。',
#    '如英語的、和有相當的關係，英語使用者能夠利用他們的背景知識來判斷此關係，對他們來說，和的關係就如同和，和就如同和。',
#    '構詞學正是研究這種單字間組成的關係，並試著整理出其組成的規則。',
#    '基本概念英文字的根基字根「」是指英文字的本根，是和的字根。',
#    '雖然三字的義意不同，也與其字的根源有所關聯。',
#    '字形（）和字詞（）和有不同的字形（）。',
#    '另一方面，和是有不同解釋的字詞（），他們所指的是不同的實體。',
#    '英文字的原形，稱爲詞條（；原形），其引用形式（），即是指可於字典上查詢的字詞的根本原形（）。'],
#   'query': '詞法學',
#   'rawtext': '詞法學（英語：morphology，“組織與形態”），又稱形態學、構詞學，是語言學的一個分支，研究單詞（word）的內部結構和其形成方式。如英語的dog、dogs和dog-catcher有相當的關係，英語使用者能夠利用他們的背景知識來判斷此關係，對他們來說，dog和dogs的關係就如同cat和cats，dog和dog-catcher就如同dish和dishwasher。構詞學正是研究這種單字間組成的關係，並試著整理出其組成的規則。\n\n\n== 基本概念 ==\n\n\n=== 英文字的根基(字根) ===\n「Lexeme」 是指英文字的本根，dog 是dogs和dog catcher 的字根。雖然三字的義意不同，也與其字的根源有所關聯。\n\n\n=== 字形（word form）和字詞（vocabulary） ===\ndog 和 cat 有不同的字形（word form） 。另一方面，Dog 和 dog catcher 是有不同解釋的字詞（vocabulary），他們所指的是不同的實體。\n英文字的原形，稱爲詞條（lemma；原形），其引用形式（citation form），即是指可於字典上查詢的字詞的根本原形（vocabulary）。\n\n\n== 構詞學模式 ==\n\n\n== 語言類型分類 ==\n\n\n== 註釋 ==\n\n\n== 延伸閱讀 ==\n\n\n== 參見 ==\n\n語素\n語法形態配列\n\n\n== 外部連結 ==\nSegmenti − Segmenti (Freeware)',
#   'title': '詞法學'}]

# %% [markdown]
# ## N-gram 探索

# %%
sentence_list = []
for article in corpus:
    sentence_list.extend(article["preproc"])

# %%
len(sentence_list), sentence_list[:3]
# Out:
# (664,
#  ['語音學（、發音：）是研究言語聲音（即語音）的語言學分支學科。',
#   '狹義的語音學對應英語中發音一詞，關切的重點在語音的物理、生物、心理等具象本質，與語音的實際用途、表達意義無關。',
#   '與之相對的是音韻學（或稱音系學），研究音位或語音區別特徵在某種語言中運作的抽象規則和語音的系統。'])

# %%
from tqdm.auto import tqdm

def get_ngrams(sentences, winsize=2):
    ngram_counter = {}    
    for sent in tqdm(sentences, desc=f"win: {winsize}"):
        for idx in range(0, len(sent)-winsize, winsize):
            ngram = sent[idx: idx+winsize]
            ngram_counter[ngram] = ngram_counter.get(ngram, 0) + 1
    ngrams = sorted(ngram_counter.items(), key=lambda x: x[1], reverse=True)
    return ngrams

# %%
bigrams = get_ngrams(sentence_list, winsize=2)
trigrams = get_ngrams(sentence_list, winsize=3)
fourgrams = get_ngrams(sentence_list, winsize=4)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='win: 2', max=664.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='win: 3', max=664.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='win: 4', max=664.0, style=ProgressStyle(description_width…

# %%
n_ng = 20
list(zip(bigrams[:n_ng], trigrams[:n_ng], fourgrams[:n_ng]))
# Out:
# [(('語言', 78), ('白羊座', 40), ('距離地球', 11)),
#  (('（）', 61), ('視星等', 27), ('每年月日', 10)),
#  (('研究', 51), ('語義學', 20), ('拉丁語：', 10)),
#  (('星座', 51), ('語言學', 20), ('亮於等的', 10)),
#  (('恆星', 51), ('金牛座', 20), ('恆星有顆', 10)),
#  (('星等', 49), ('獅子座', 19), ('，最亮星', 10)),
#  (('光年', 48), ('球光年', 16), ('過上中天', 10)),
#  (('白羊', 47), ('室女座', 16), ('視星等的', 9)),
#  (('視星', 43), ('寶瓶座', 15), ('地球光年', 9)),
#  (('一個', 41), ('星等爲', 14), ('，天文符', 9)),
#  (('），', 39), ('雙子座', 14), ('座中心經', 9)),
#  (('星，', 38), ('人馬座', 14), ('心理語言', 8)),
#  (('子座', 37), ('流星雨', 13), ('），視星', 8)),
#  (('座的', 36), ('星系，', 13), ('重要主星', 8)),
#  (('語法', 34), ('（），', 12), ('的語義學', 7)),
#  (('語義', 34), ('每年月', 12), ('白羊座是', 7)),
#  (('星系', 34), ('距離地', 12), ('絕對星等', 7)),
#  (('獅子', 34), ('天秤座', 12), ('表深空天', 7)),
#  (('羊座', 33), ('雙魚座', 12), ('語言學的', 6)),
#  (('地球', 33), ('的研究', 11), ('生成語法', 6))]

# %%
target = "球光年"
for sent in sentence_list:
    if target not in sent: continue
    idx = sent.index(target)    
    print("{:>20}\t{}\t{:<20}".format(
        sent[max(idx-10, 0):idx].rjust(20, "\u3000"), target, 
        sent[idx+len(target):idx+len(target)+10]))
# Out:
# 　　　　　　　　　　視星等的橙巨星，距地	球光年	。
# 　　　　　　　　　　　　　　　婁宿一離地	球光年	，絕對星等，光度是太
# 　　　　　　　　　　　　　　　婁宿二距地	球光年	，雙星中的主星是視星
# 　　　　　　　　　　等，從星視星等，離地	球光年	。
# 　　　　　　　　　　　　　　　　主星距地	球光年	，絕對星等，光譜等級
# 　　　　　　　　　　較大，相隔角秒，距地	球光年	，內部從星爲視星等。
# 　　　　　　　　　　　　　　　　　如離地	球光年	的天陰四就是視星等，
# 　　　　　　　　　　　視星等的天陰二距地	球光年	，光譜等級，絕對星等
# 　　　　　　　　　　　　　　　　　　離地	球光年	的婁宿增九爲視星等，
# 　　　　　　　　　　　視星等的胃宿二距地	球光年	，光譜等級，絕對星等
# 　　　　　　　　　　星等的暗淡恆星，離地	球光年	，光譜等級，絕對星等
# 　　　　　　　　　　亮，視星等達到，距地	球光年	，光譜等級，光度是太
# 　　　　　　　　　　視星等的速逃星，離地	球光年	遠，光譜等級，估計是
# 　　　　　　　　　　視星等範圍變化，距地	球光年	。
# 　　　　　　　　　　，最亮時視星等，距地	球光年	。
# 　　　　　　　　　　亮星，視星等，距離地	球光年	，雖位於畢星團內，但
# 　　　　　　　　　　亮星，視星等，距離地	球光年	。
# 　　　　　　　　　　　　　　　　　距離地	球光年	。
# 　　　　　　　　　　　　　　　　它距離地	球光年	，是最接近太陽系的星
# 　　　　　　　　　　利澤，紅矮星，距離地	球光年	，目前已發現一個行星
# 　　　　　　　　　　疏散星團，即，距離地	球光年	。
# 　　　　　　　　　　的星雲狀物質，距離地	球光年	。
# 　　　　　　　　　　星等到的天體，距離地	球光年	。
# 　　　　　　　　　　　　　　　　　距離地	球光年	，其中熾熱年輕的恆星
# 　　　　　　　　　　見，總星等為，距離地	球光年	。
# 　　　　　　　　　　　它的星等是，距離地	球光年	。
# 　　　　　　　　　　　　　　　　　距離地	球光年	。
# 　　　　　　　　　　，它的星等是，距離地	球光年	。
# 　　　　　　　　　　　　其星等是，距離地	球光年	。
# 　　　　　　　　　　　　　　　　　距離地	球光年	。
# 　　　　　　　　　　　　　　　　　距離地	球光年	。
# 　　　　　　　　　　　　　　　　　距離地	球光年	。
# 　　　　　　　　　　利澤，紅矮星，距離地	球光年	。

# %%
corpus[16]
# Out:
# {'preproc': ['雙魚座（希臘語，天文符號：）是黃道星座之一，面積平方度，佔全天面積的，在全天個星座中，面積排行第十四。',
#   '雙魚座每年月日子夜中心經過上中天。',
#   '雙魚座中亮於等的恆星有顆，最亮星爲右更二（雙魚座），視星等爲。',
#   '現在的春分點位於霹靂五（雙魚座）附近。',
#   '特點雙魚座雖然是較大的星座，但組成星座的恆星都很暗。',
#   '雙魚座最容易辨認的是兩個雙魚座小環，特別是緊貼飛馬座南面由雙魚座、、、、、等恆星組成的六邊形小環，另一個雙魚座小環位於飛馬座東面，由雙魚座、、、、、等恆星組成。',
#   '這個星座有一個梅西耶天體：，位於雙魚座最亮星右更二附近。',
#   '神話故事希臘神話中雙魚座代表的是阿佛洛狄忒和厄洛斯在水中的化身。',
#   '阿佛洛狄忒爲了逃避大地女神蓋亞之子巨神提豐攻擊而變成魚躲在尼羅河（一說幼發拉底河）。',
#   '之後她發現忘記帶上自己的兒子厄洛斯一起逃走，於是又上岸找到厄洛斯。',
#   '爲防止與兒子失散，她將兩人腳綁在一起，隨後兩人化爲魚形，潛進河中。',
#   '事後宙斯將阿佛洛狄忒首先化身的魚提升到空中成爲南魚座，而她和厄洛斯化身的綁在一起的兩條魚則稱爲雙魚座。',
#   '恆星外屏七（雙魚座），雙星，在望遠鏡中可以看到一顆呈黃色，一顆呈藍色。',
#   '主星視星等，伴星爲，複合星等。',
#   '外屏三（雙魚座），雙星，兩子星一顆呈淺黃色，一顆呈淺紅色。',
#   '主星視星等，伴星爲，複合星等。',
#   '土公二（雙魚座，雙魚座），半規則變星，亮度介於之間，變光周期爲日。',
#   '雲雨增七（雙魚座，雙魚座），不規則變星，亮度介於之間。',
#   '範馬南星（），白矮星，視星等，距離爲光年，是雙魚座中離地球最近的恆星。',
#   '範馬南星是人類發現的第三顆白矮星，也是第一顆不在多恆星系統中發現的白矮星。',
#   '重要主星表中國星官中國古代傳統將雙魚座天區包括壁宿的霹靂、雲雨、土公，奎宿的奎、外屏和婁宿的右更等星官。'],
#  'query': '雙魚座',
#  'rawtext': "雙魚座（Template:希臘語 moon，天文符號：♓）是黃道星座之一，面積889.42平方度，佔全天面積的2.156%，在全天88個星座中，面積排行第十四。雙魚座每年9月27日子夜中心經過上中天。雙魚座中亮於5.5等的恆星有50顆，最亮星爲右更二（雙魚座η），視星等爲3.62。現在的春分點位於霹靂五（雙魚座ω）附近。\n\n\n== 特點 ==\n\n雙魚座雖然是較大的星座，但組成星座的恆星都很暗。雙魚座最容易辨認的是兩個雙魚座小環，特別是緊貼飛馬座南面由雙魚座β、γ、θ、ι、χ、λ等恆星組成的六邊形小環，另一個雙魚座小環位於飛馬座東面，由雙魚座σ、τ、υ、φ、χ、ψ1等恆星組成。\n這個星座有一個梅西耶天體：M74，位於雙魚座最亮星右更二附近。\n\n\n== 神話故事 ==\n\n希臘神話中雙魚座代表的是阿佛洛狄忒和厄洛斯在水中的化身。阿佛洛狄忒爲了逃避大地女神蓋亞之子巨神提豐攻擊而變成魚躲在尼羅河（一說幼發拉底河）。之後她發現忘記帶上自己的兒子厄洛斯一起逃走，於是又上岸找到厄洛斯。爲防止與兒子失散，她將兩人腳綁在一起，隨後兩人化爲魚形，潛進河中。事後宙斯將阿佛洛狄忒首先化身的魚提升到空中成爲南魚座，而她和厄洛斯化身的綁在一起的兩條魚則稱爲雙魚座。\n\n\n== 恆星 ==\n外屏七（雙魚座α），雙星，在望遠鏡中可以看到一顆呈黃色，一顆呈藍色。主星視星等4.2，伴星爲5.3，複合星等3.8。\n外屏三（雙魚座ζ），雙星，兩子星一顆呈淺黃色，一顆呈淺紅色。主星視星等5.6，伴星爲6.3，複合星等5.2。\n土公二（雙魚座TV，雙魚座47），半規則變星，亮度介於4.65-5.42之間，變光周期爲49.1日。\n雲雨增七（雙魚座TX，雙魚座19），不規則變星，亮度介於4.79-5.20之間。\n範馬南星（Van Maanen's star），白矮星，視星等12.36，距離爲14.1光年，是雙魚座中離地球最近的恆星。範馬南星是人類發現的第三顆白矮星，也是第一顆不在多恆星系統中發現的白矮星。\n\n\n=== 重要主星表 ===\n\n\n== 中國星官 ==\n中國古代傳統將雙魚座天區包括壁宿的霹靂、雲雨、土公，奎宿的奎、外屏和婁宿的右更等星官。\n\n霹靂 Thunderbolt（壁5）：雙魚座β、γ、θ、ι、ω\n雲雨 Cloud and Rain（壁4）：雙魚座χ、14、21、λ\n土公 Official for Earthworks and Buildings（壁2）：雙魚座32、47\n奎 Legs（奎16）：雙魚座σ、τ、υ、φ、χ、ψ1\n外屏 Outer Fence（奎7）：雙魚座δ、ε、ζ、μ、ν、ξ、α\n右更 Official in Charge of Pasturing（婁5）：雙魚座ρ、η、π、ο、101\n\n\n== 流行文化 ==\n在爆旋陀螺 鋼鐵戰魂中，陀螺手深海流太郎所持有的陀螺是鱗光雙魚D125BS/熱流雙魚T125ES，它擁有雙魚座的力量\n\n\n== 參考資料 ==\n\nAEEA 天文教育資訊網 璧宿天區 頁面存檔備份，存於互聯網檔案館\nAEEA 天文教育資訊網 奎宿天區 頁面存檔備份，存於互聯網檔案館\n《星座與希臘神話》\n\n\n== 外部連結 ==\nThe Deep Photographic Guide to the Constellations: Pisces 頁面存檔備份，存於互聯網檔案館\nStar Tales – Pisces 頁面存檔備份，存於互聯網檔案館",
#  'title': '雙魚座'}

# %%
test_text = "之後她發現忘記帶上自己的兒子厄洛斯一起逃走，於是又上岸找到厄洛斯。"

# %%
import jieba
jieba.lcut(test_text)
user_dict=["厄洛斯"]
for w in user_dict:
    jieba.add_word(w)
jieba.lcut(test_text)
# Out:
# Building prefix dict from /content/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# Loading model cost 1.526 seconds.
# Prefix dict has been built successfully.
# ['之後',
#  '她',
#  '發現',
#  '忘記',
#  '帶上',
#  '自己',
#  '的',
#  '兒子',
#  '厄洛斯',
#  '一起',
#  '逃走',
#  '，',
#  '於是',
#  '又',
#  '上岸',
#  '找到',
#  '厄洛斯',
#  '。']

# %% [markdown]
# ## DistilTag & CwnSenseTagge

# %%
import DistilTag, CwnSenseTagger
DistilTag.download()
CwnSenseTagger.download()
# Out:
# A copy of DistilTag model already exists. Use upgrade=True to overwrite
# A copy of DistilTag model already exists. Use upgrade=True to overwrite

# %%
# DistilTag是斷詞及詞性標記用，也可以使用CkipTagger
# https://github.com/ckiplab/ckiptagger
from DistilTag import DistilTag      

# senseTag是CwnSenseTagger的主要標記函式
from CwnSenseTagger import senseTag

# %%
import CwnSenseTagger

# %%
tagger = DistilTag()
tagged = tagger.tag(test_text)
tagged
# Out:
# [[('之後', 'Nd'),
#   ('她', 'Nh'),
#   ('發現', 'VE'),
#   ('忘記', 'VK'),
#   ('帶上', 'VC'),
#   ('自己', 'Nh'),
#   ('的', 'DE'),
#   ('兒子', 'Na'),
#   ('厄洛斯', 'Nb'),
#   ('一起', 'D'),
#   ('逃走', 'VA'),
#   ('，', 'COMMACATEGORY')],
#  [('於是', 'Cbb'),
#   ('又', 'D'),
#   ('上岸', 'VA'),
#   ('找到', 'VC'),
#   ('厄洛斯', 'Nb'),
#   ('。', 'PERIODCATEGORY')]]

# %%
sense_tagged = senseTag(tagged)
sense_tagged
# Out:
# [[['之後', 'Nd', '03056402', '晚於現在或前述事件的時段。'],
#   ['她', 'Nh', '05124901', '代指自己和對方以外的單數女性第三者，指人。'],
#   ['發現', 'VE', '', ''],
#   ['忘記', 'VK', '05074602', '沒有給後述對象應有的重視。'],
#   ['帶上', 'VC', '', ''],
#   ['自己', 'Nh', '05076901', '代指主事者。'],
#   ['的', 'DE', '07023402', '表領屬關係，用於修飾語和中心語間。'],
#   ['兒子', 'Na', '06662901', '父母對自己所生育的男性後代的指稱。'],
#   ['厄洛斯', 'Nb', '', ''],
#   ['一起', 'D', '04162502', '表不同的主體在同一空間或進行同一事件。'],
#   ['逃走', 'VA', '', ''],
#   ['，', 'COMMACATEGORY', '', '']],
#  [['於是', 'Cbb', '04030601', '連接結果句，用來承接上半句的原因。'],
#   ['又', 'D', '04000903', '表事件重複發生。'],
#   ['上岸', 'VA', '', ''],
#   ['找到', 'VC', '06609501', '搜尋到需要的後述對象，強調動作的結果。'],
#   ['厄洛斯', 'Nb', '', ''],
#   ['。', 'PERIODCATEGORY', '', '']]]

# %% [markdown]
# ## 中文詞彙網路資料

# %%
import CwnGraph
from CwnGraph import CwnBase, CwnSense
CwnGraph.download()
cwn = CwnBase()

# %%
cwn.find_lemma("^喝$")
# Out:
# [<CwnLemma: 喝_1>, <CwnLemma: 喝_2>]

# %%
cwn.find_senses("^喝$")
# Out:
# [<CwnSense[05226901](喝): 將液體或糊狀的食物經由口中進入體內並吸收養分。>,
#  <CwnSense[05226902](喝): 專指喝酒。>,
#  <CwnSense[05226903](喝): 經歷後述包括飲食的社交聚會。>,
#  <CwnSense[06048101](喝): 以兇狠的態度大聲叫喊。>,
#  <CwnSense[06048102](喝): 表不屑的語氣，程度較「哼」、「呸」為低。>]

# %%
CwnSense("05074602", cwn).semantic_relations
# Out:
# [('synonym', <CwnSense[05123202](忘): 沒有給後述對象應有的重視。>, 'forward'),
#  ('synonym', <CwnSense[05123202](忘): 沒有給後述對象應有的重視。>, 'reversed')]

# %% [markdown]
# ## CKIPTagger

# %% [markdown]
# ### Loading CKIP Model

# %%
from ckiptagger import construct_dictionary, WS, POS, NER
import os
from ckiptagger import data_utils

if not os.path.exists("./ckiptagger/data"):
    data_utils.download_data_gdown("./ckiptagger")
    # 備用：如果google drive限流，可用以下這行從中研院IIS下載
    # data_utils.download_data_url("./ckiptagger")

# %% [markdown]
# ### CKIP CoreNLP Pipeline

# %%
ws = WS("./ckiptagger/data")
pos = POS("./ckiptagger/data")
ner = NER("./ckiptagger/data")

# %%
def ckip_tag(text):
    words = ws([text])
    pos_list = pos(words)
    
    words_list = []
    for words_x, pos_list_x in zip(words, pos_list):
        print("\u3000".join(f"{w}({p})" for w, p in zip(words_x, pos_list_x)))
        words_list.append([[w, p] for w, p in zip(words_x, pos_list_x)])
    ner_list = ner(words, pos_list)
    return (words_list, ner_list[0])

# %%
words, ners = ckip_tag(test_text)
# Out:
# 之後(Nd)　她(Nh)　發現(VE)　忘記(VK)　帶上(VC)　自己(Nh)　的(DE)　兒子(Na)　厄洛斯(Nb)　一起(D)　逃走(VA)　，(COMMACATEGORY)　於是(Cbb)　又(D)　上岸(VA)　找到(VC)　厄洛斯(Nb)　。(PERIODCATEGORY)

# %%
words, ners
# Out:
# ([[['之後', 'Nd'],
#    ['她', 'Nh'],
#    ['發現', 'VE'],
#    ['忘記', 'VK'],
#    ['帶上', 'VC'],
#    ['自己', 'Nh'],
#    ['的', 'DE'],
#    ['兒子', 'Na'],
#    ['厄洛斯', 'Nb'],
#    ['一起', 'D'],
#    ['逃走', 'VA'],
#    ['，', 'COMMACATEGORY'],
#    ['於是', 'Cbb'],
#    ['又', 'D'],
#    ['上岸', 'VA'],
#    ['找到', 'VC'],
#    ['厄洛斯', 'Nb'],
#    ['。', 'PERIODCATEGORY']]],
#  {(14, 17, 'PERSON', '厄洛斯'), (29, 32, 'PERSON', '厄洛斯')})

# %% [markdown]
# ### 準備自動標記語料

# %%
from tqdm.auto import tqdm
tagger = DistilTag()
for article in tqdm(corpus):
    tagged_list = []
    for seq in article["preproc"]:
        try:
            tagged = tagger.tag(seq)
            tagged_seq = []
            for tagged_sent in tagged:
                tagged_seq.extend([
                    {"word": x[0], "pos": x[1]}
                    for x in tagged_sent])
            tagged_list.append(tagged_seq)
            
        except Exception as ex:
            print(f"{ex}: ", seq)
    # uncomment the following line to tag the full corpus        
    # article["tagged"] = tagged_list
    # comment the following line to tag the full corpus
    break
# Out:
# HBox(children=(FloatProgress(value=0.0, max=17.0), HTML(value='')))

# %%
tagged_list
# Out:
# [[{'pos': 'Na', 'word': '語音學'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '發音'},
#   {'pos': 'COLONCATEGORY', 'word': '：'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'VE', 'word': '研究'},
#   {'pos': 'Na', 'word': '言語'},
#   {'pos': 'Na', 'word': '聲音'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#   {'pos': 'VG', 'word': '即'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '）'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '語言學'},
#   {'pos': 'Na', 'word': '分支'},
#   {'pos': 'Na', 'word': '學科'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '狹義'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'VC', 'word': '對應'},
#   {'pos': 'Na', 'word': '英語'},
#   {'pos': 'Ng', 'word': '中'},
#   {'pos': 'Na', 'word': '發音'},
#   {'pos': 'Neu', 'word': '一'},
#   {'pos': 'Na', 'word': '詞'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'VJ', 'word': '關切'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '重點'},
#   {'pos': 'P', 'word': '在'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '物理'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '生物'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '心理'},
#   {'pos': 'Cab', 'word': '等'},
#   {'pos': 'VH', 'word': '具象'},
#   {'pos': 'Na', 'word': '本質'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'P', 'word': '與'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'VH', 'word': '實際'},
#   {'pos': 'Na', 'word': '用途'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Nv', 'word': '表達'},
#   {'pos': 'Na', 'word': '意義'},
#   {'pos': 'VH', 'word': '無關'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'P', 'word': '與'},
#   {'pos': 'Nh', 'word': '之'},
#   {'pos': 'VH', 'word': '相對'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'Na', 'word': '音韻學'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#   {'pos': 'Caa', 'word': '或'},
#   {'pos': 'VG', 'word': '稱'},
#   {'pos': 'Na', 'word': '音系學'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '）'},
#   {'pos': 'VE', 'word': '研究'},
#   {'pos': 'Na', 'word': '音位'},
#   {'pos': 'Caa', 'word': '或'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'Na', 'word': '區別'},
#   {'pos': 'Na', 'word': '特徵'},
#   {'pos': 'P', 'word': '在'},
#   {'pos': 'Nes', 'word': '某'},
#   {'pos': 'Nf', 'word': '種'},
#   {'pos': 'Na', 'word': '語言'},
#   {'pos': 'Ng', 'word': '中'},
#   {'pos': 'VA', 'word': '運作'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'VH', 'word': '抽象'},
#   {'pos': 'Na', 'word': '規則'},
#   {'pos': 'Caa', 'word': '和'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '系統'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '廣義'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'VG', 'word': '指'},
#   {'pos': 'Nep', 'word': '這'},
#   {'pos': 'Neu', 'word': '兩'},
#   {'pos': 'VH', 'word': '大'},
#   {'pos': 'Na', 'word': '方面'},
#   {'pos': 'Nv', 'word': '研究'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '總合'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Nes', 'word': '本'},
#   {'pos': 'Na', 'word': '文'},
#   {'pos': 'VE', 'word': '介紹'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'Na', 'word': '狹義'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '語音'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'Nv', 'word': '研究'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '客體'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'VG', 'word': '指'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'Na', 'word': '人類'},
#   {'pos': 'VA', 'word': '說話'},
#   {'pos': 'Ng', 'word': '時'},
#   {'pos': 'VC', 'word': '發出'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'VH', 'word': '具體'},
#   {'pos': 'Na', 'word': '聲音'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'VG', 'word': '即'},
#   {'pos': 'Na', 'word': '言語'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '聲音'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Nc', 'word': '國際'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'Nc', 'word': '學會'},
#   {'pos': 'D', 'word': '所'},
#   {'pos': 'VC', 'word': '制訂'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Nc', 'word': '國際'},
#   {'pos': 'Na', 'word': '音標'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'Nc', 'word': '語言學界'},
#   {'pos': 'VH', 'word': '廣泛'},
#   {'pos': 'VL', 'word': '用來'},
#   {'pos': 'VC', 'word': '標註'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '音標'},
#   {'pos': 'Na', 'word': '方案'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '學科'},
#   {'pos': 'VC', 'word': '分支'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Nv', 'word': '研究'},
#   {'pos': 'Na', 'word': '範疇'},
#   {'pos': 'VK', 'word': '包括'},
#   {'pos': 'Ncd', 'word': '以下'},
#   {'pos': 'Neu', 'word': '三'},
#   {'pos': 'Nf', 'word': '類'},
#   {'pos': 'COLONCATEGORY', 'word': '：'},
#   {'pos': 'Na', 'word': '發音'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'COLONCATEGORY', 'word': '：'},
#   {'pos': 'Nep', 'word': '此'},
#   {'pos': 'VC', 'word': '分'},
#   {'pos': 'Nc', 'word': '科'},
#   {'pos': 'VE', 'word': '研究'},
#   {'pos': 'Na', 'word': '發音'},
#   {'pos': 'Na', 'word': '器官'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#   {'pos': 'P', 'word': '如'},
#   {'pos': 'Na', 'word': '脣'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '齒'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '舌'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '聲門'},
#   {'pos': 'Cab', 'word': '等'},
#   {'pos': 'PARENTHESISCATEGORY', 'word': '）'},
#   {'pos': 'D', 'word': '如何'},
#   {'pos': 'Nh', 'word': '彼此'},
#   {'pos': 'VC', 'word': '協調'},
#   {'pos': 'Na', 'word': '動作'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'Cbb', 'word': '以'},
#   {'pos': 'VC', 'word': '發出'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '聲'},
#   {'pos': 'VC', 'word': '學'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'COLONCATEGORY', 'word': '：'},
#   {'pos': 'Nep', 'word': '此'},
#   {'pos': 'VC', 'word': '分'},
#   {'pos': 'Nf', 'word': '科'},
#   {'pos': 'VE', 'word': '研究'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '物理'},
#   {'pos': 'Na', 'word': '現象'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'P', 'word': '如'},
#   {'pos': 'Na', 'word': '聲波'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '頻率'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '時長'},
#   {'pos': 'PAUSECATEGORY', 'word': '、'},
#   {'pos': 'Na', 'word': '振幅'},
#   {'pos': 'Cab', 'word': '等'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '聽覺'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'COLONCATEGORY', 'word': '：'},
#   {'pos': 'Nep', 'word': '此'},
#   {'pos': 'VC', 'word': '分'},
#   {'pos': 'Nf', 'word': '科'},
#   {'pos': 'VE', 'word': '研究'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Nv', 'word': '感知'},
#   {'pos': 'Na', 'word': '歷程'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '歷史'},
#   {'pos': 'VH', 'word': '現代'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'D', 'word': '最早'},
#   {'pos': 'Na', 'word': '發展'},
#   {'pos': 'SHI', 'word': '是'},
#   {'pos': 'P', 'word': '為'},
#   {'pos': 'Di', 'word': '了'},
#   {'pos': 'VC', 'word': '發明出'},
#   {'pos': 'Neu', 'word': '一'},
#   {'pos': 'Nf', 'word': '套'},
#   {'pos': 'VE', 'word': '記錄'},
#   {'pos': 'Na', 'word': '語音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Na', 'word': '記號'},
#   {'pos': 'Na', 'word': '系統'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}],
#  [{'pos': 'Na', 'word': '世紀'},
#   {'pos': 'Nd', 'word': '後期'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'Na', 'word': '留聲機'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Nv', 'word': '出現'},
#   {'pos': 'VL', 'word': '令'},
#   {'pos': 'P', 'word': '到'},
#   {'pos': 'Na', 'word': '聲音'},
#   {'pos': 'DE', 'word': '的'},
#   {'pos': 'Nv', 'word': '研究'},
#   {'pos': 'Dfa', 'word': '更為'},
#   {'pos': 'VH', 'word': '方便'},
#   {'pos': 'COMMACATEGORY', 'word': '，'},
#   {'pos': 'VL', 'word': '令到'},
#   {'pos': 'Na', 'word': '語音學'},
#   {'pos': 'VH', 'word': '快速'},
#   {'pos': 'VC', 'word': '發展'},
#   {'pos': 'PERIODCATEGORY', 'word': '。'}]]

# %%
with open("data_1.4/corpus-wiki.tagged.json", "r", encoding="UTF-8") as fin:
    tagged_corpus = json.load(fin)

# %%
tagged_corpus[0]
# Out:
# {'preproc': ['語音學（、發音：）是研究言語聲音（即語音）的語言學分支學科。',
#   '狹義的語音學對應英語中發音一詞，關切的重點在語音的物理、生物、心理等具象本質，與語音的實際用途、表達意義無關。',
#   '與之相對的是音韻學（或稱音系學），研究音位或語音區別特徵在某種語言中運作的抽象規則和語音的系統。',
#   '廣義的語音學是指這兩大方面研究的總合。',
#   '本文介紹的是狹義的語音學。',
#   '語音是語音學研究的客體，指的是人類說話時發出的具體聲音，即言語的聲音。',
#   '國際語音學學會所制訂的國際音標是語言學界廣泛用來標註語音的音標方案。',
#   '學科分支語音學的研究範疇包括以下三類：發音語音學：此分科研究發音器官（如脣、齒、舌、聲門等）如何彼此協調動作，以發出語音。',
#   '聲學語音學：此分科研究語音的物理現象，如聲波的頻率、時長、振幅等。',
#   '聽覺語音學：此分科研究語音的感知歷程。',
#   '歷史現代語音學的最早發展是為了發明出一套記錄語音的記號系統。',
#   '世紀後期，留聲機的出現令到聲音的研究更為方便，令到語音學快速發展。'],
#  'query': '語音學',
#  'rawtext': '語音學（Phonetics、發音：/fəˈnɛtɪks/）是研究言語聲音（即語音）的語言學分支學科。狹義的語音學對應英語中phonetics(發音)一詞，關切的重點在語音的物理、生物、心理等具象本質，與語音的實際用途、表達意義無關。與之相對的是音韻學（或稱音系學），研究音位或語音區別特徵在某種語言中運作的抽象規則和語音的系統。廣義的語音學是指這兩大方面研究的總合。本文介紹的是狹義的語音學。\n語音是語音學研究的客體，指的是人類說話時發出的具體聲音，即言語的聲音。\n國際語音學學會所制訂的國際音標是語言學界廣泛用來標註語音的音標方案。\n\n\n== 學科分支 ==\n語音學的研究範疇包括以下三類：\n\n發音語音學 (articulatory phonetics)：此分科研究發音器官（如脣、齒、舌、聲門等）如何彼此協調動作，以發出語音。\n聲學語音學 (acoustic phonetics)：此分科研究語音的物理現象，如聲波的頻率、時長、振幅等。\n聽覺語音學 (auditory phonetics)：此分科研究語音的感知歷程。\n\n\n== 歷史 ==\n現代語音學的最早發展是為了發明出一套記錄語音的記號系統。19世紀後期，留聲機的出現令到聲音的研究更為方便，令到語音學快速發展。\n\n\n== 註釋 ==\n\n\n== 參考文獻 ==\n\n\n== 參見 ==\n\n實驗語音學\n\n\n== 外部鏈接 ==\n\n國際語音學學會\nOn-line phonetics course',
#  'tagged': [[{'pos': 'Na', 'word': '語音學'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '發音'},
#    {'pos': 'COLONCATEGORY', 'word': '：'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'VE', 'word': '研究'},
#    {'pos': 'Na', 'word': '言語'},
#    {'pos': 'Na', 'word': '聲音'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#    {'pos': 'VG', 'word': '即'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '）'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '語言學'},
#    {'pos': 'Na', 'word': '分支'},
#    {'pos': 'Na', 'word': '學科'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '狹義'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'VC', 'word': '對應'},
#    {'pos': 'Na', 'word': '英語'},
#    {'pos': 'Ng', 'word': '中'},
#    {'pos': 'Na', 'word': '發音'},
#    {'pos': 'Neu', 'word': '一'},
#    {'pos': 'Na', 'word': '詞'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'VJ', 'word': '關切'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '重點'},
#    {'pos': 'P', 'word': '在'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '物理'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '生物'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '心理'},
#    {'pos': 'Cab', 'word': '等'},
#    {'pos': 'VH', 'word': '具象'},
#    {'pos': 'Na', 'word': '本質'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'P', 'word': '與'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'VH', 'word': '實際'},
#    {'pos': 'Na', 'word': '用途'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Nv', 'word': '表達'},
#    {'pos': 'Na', 'word': '意義'},
#    {'pos': 'VH', 'word': '無關'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'P', 'word': '與'},
#    {'pos': 'Nh', 'word': '之'},
#    {'pos': 'VH', 'word': '相對'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'Na', 'word': '音韻學'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#    {'pos': 'Caa', 'word': '或'},
#    {'pos': 'VG', 'word': '稱'},
#    {'pos': 'Na', 'word': '音系學'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '）'},
#    {'pos': 'VE', 'word': '研究'},
#    {'pos': 'Na', 'word': '音位'},
#    {'pos': 'Caa', 'word': '或'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'Na', 'word': '區別'},
#    {'pos': 'Na', 'word': '特徵'},
#    {'pos': 'P', 'word': '在'},
#    {'pos': 'Nes', 'word': '某'},
#    {'pos': 'Nf', 'word': '種'},
#    {'pos': 'Na', 'word': '語言'},
#    {'pos': 'Ng', 'word': '中'},
#    {'pos': 'VA', 'word': '運作'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'VH', 'word': '抽象'},
#    {'pos': 'Na', 'word': '規則'},
#    {'pos': 'Caa', 'word': '和'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '系統'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '廣義'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'VG', 'word': '指'},
#    {'pos': 'Nep', 'word': '這'},
#    {'pos': 'Neu', 'word': '兩'},
#    {'pos': 'VH', 'word': '大'},
#    {'pos': 'Na', 'word': '方面'},
#    {'pos': 'Nv', 'word': '研究'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '總合'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Nes', 'word': '本'},
#    {'pos': 'Na', 'word': '文'},
#    {'pos': 'VE', 'word': '介紹'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'Na', 'word': '狹義'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '語音'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'Nv', 'word': '研究'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '客體'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'VG', 'word': '指'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'Na', 'word': '人類'},
#    {'pos': 'VA', 'word': '說話'},
#    {'pos': 'Ng', 'word': '時'},
#    {'pos': 'VC', 'word': '發出'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'VH', 'word': '具體'},
#    {'pos': 'Na', 'word': '聲音'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'VG', 'word': '即'},
#    {'pos': 'Na', 'word': '言語'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '聲音'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Nc', 'word': '國際'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'Nc', 'word': '學會'},
#    {'pos': 'D', 'word': '所'},
#    {'pos': 'VC', 'word': '制訂'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Nc', 'word': '國際'},
#    {'pos': 'Na', 'word': '音標'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'Nc', 'word': '語言學界'},
#    {'pos': 'VH', 'word': '廣泛'},
#    {'pos': 'VL', 'word': '用來'},
#    {'pos': 'VC', 'word': '標註'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '音標'},
#    {'pos': 'Na', 'word': '方案'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '學科'},
#    {'pos': 'VC', 'word': '分支'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Nv', 'word': '研究'},
#    {'pos': 'Na', 'word': '範疇'},
#    {'pos': 'VK', 'word': '包括'},
#    {'pos': 'Ncd', 'word': '以下'},
#    {'pos': 'Neu', 'word': '三'},
#    {'pos': 'Nf', 'word': '類'},
#    {'pos': 'COLONCATEGORY', 'word': '：'},
#    {'pos': 'Na', 'word': '發音'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'COLONCATEGORY', 'word': '：'},
#    {'pos': 'Nep', 'word': '此'},
#    {'pos': 'VC', 'word': '分'},
#    {'pos': 'Nc', 'word': '科'},
#    {'pos': 'VE', 'word': '研究'},
#    {'pos': 'Na', 'word': '發音'},
#    {'pos': 'Na', 'word': '器官'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '（'},
#    {'pos': 'P', 'word': '如'},
#    {'pos': 'Na', 'word': '脣'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '齒'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '舌'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '聲門'},
#    {'pos': 'Cab', 'word': '等'},
#    {'pos': 'PARENTHESISCATEGORY', 'word': '）'},
#    {'pos': 'D', 'word': '如何'},
#    {'pos': 'Nh', 'word': '彼此'},
#    {'pos': 'VC', 'word': '協調'},
#    {'pos': 'Na', 'word': '動作'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'Cbb', 'word': '以'},
#    {'pos': 'VC', 'word': '發出'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '聲'},
#    {'pos': 'VC', 'word': '學'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'COLONCATEGORY', 'word': '：'},
#    {'pos': 'Nep', 'word': '此'},
#    {'pos': 'VC', 'word': '分'},
#    {'pos': 'Nf', 'word': '科'},
#    {'pos': 'VE', 'word': '研究'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '物理'},
#    {'pos': 'Na', 'word': '現象'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'P', 'word': '如'},
#    {'pos': 'Na', 'word': '聲波'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '頻率'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '時長'},
#    {'pos': 'PAUSECATEGORY', 'word': '、'},
#    {'pos': 'Na', 'word': '振幅'},
#    {'pos': 'Cab', 'word': '等'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '聽覺'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'COLONCATEGORY', 'word': '：'},
#    {'pos': 'Nep', 'word': '此'},
#    {'pos': 'VC', 'word': '分'},
#    {'pos': 'Nf', 'word': '科'},
#    {'pos': 'VE', 'word': '研究'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Nv', 'word': '感知'},
#    {'pos': 'Na', 'word': '歷程'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '歷史'},
#    {'pos': 'VH', 'word': '現代'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'D', 'word': '最早'},
#    {'pos': 'Na', 'word': '發展'},
#    {'pos': 'SHI', 'word': '是'},
#    {'pos': 'P', 'word': '為'},
#    {'pos': 'Di', 'word': '了'},
#    {'pos': 'VC', 'word': '發明出'},
#    {'pos': 'Neu', 'word': '一'},
#    {'pos': 'Nf', 'word': '套'},
#    {'pos': 'VE', 'word': '記錄'},
#    {'pos': 'Na', 'word': '語音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Na', 'word': '記號'},
#    {'pos': 'Na', 'word': '系統'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}],
#   [{'pos': 'Na', 'word': '世紀'},
#    {'pos': 'Nd', 'word': '後期'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'Na', 'word': '留聲機'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Nv', 'word': '出現'},
#    {'pos': 'VL', 'word': '令'},
#    {'pos': 'P', 'word': '到'},
#    {'pos': 'Na', 'word': '聲音'},
#    {'pos': 'DE', 'word': '的'},
#    {'pos': 'Nv', 'word': '研究'},
#    {'pos': 'Dfa', 'word': '更為'},
#    {'pos': 'VH', 'word': '方便'},
#    {'pos': 'COMMACATEGORY', 'word': '，'},
#    {'pos': 'VL', 'word': '令到'},
#    {'pos': 'Na', 'word': '語音學'},
#    {'pos': 'VH', 'word': '快速'},
#    {'pos': 'VC', 'word': '發展'},
#    {'pos': 'PERIODCATEGORY', 'word': '。'}]],
#  'title': '語音學'}
